# %% [markdown]
# # Important methods in Series and DataFrame data structure of Pandas

# %% [markdown]
# We will be using [Titanic Dataset](https://storage.googleapis.com/kagglesdsdata/competitions/3136/26502/train.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1590354504&Signature=ZMd9%2Bl1UZNJ7zUJGdtU4%2B7Pe2V%2F2NKCK3doQ5IaCyb5%2BU9dXhXxwxY7AoAb6ezX6IO5rheShv%2FFHBL58q3joBK%2Fy8dX%2BU7cqsSsBicfTUli%2BBoVKKFXtUe76mfRmWg3S6TmJzCjbOHTZB3%2F%2FUGDQRv81t7uKAyBcHBdPQvOPJSciao9zm4Jvy8RrFbU%2BrMn2VjQGHV%2BUvI6J%2FMGXQu3SNacqI6POAie2LK6tO9Mba8hMhZ8u7NmAhwujpqEmysjNgXNWuj8PRi6IUytPIjPeOeNHiNfSPFLJSll6fldiQkHEjN4ajEqSnl4hlwBxwqkhaSK1bttNLsAS6AUIG3R0hg%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain.csv)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# ## Configuring Pandas

# %% [markdown]
# #### Available Options:-

# %% [markdown]
# <table class="table">
# <colgroup>
# <col style="width: 33%">
# <col style="width: 10%">
# <col style="width: 57%">
# </colgroup>
# <thead>
# <tr class="row-odd"><th class="head"><p>Option</p></th>
# <th class="head"><p>Default</p></th>
# <th class="head"><p>Function</p></th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even"><td><p>display.chop_threshold</p></td>
# <td><p>None</p></td>
# <td><p>If set to a float value, all float
# values smaller then the given
# threshold will be displayed as
# exactly 0 by repr and friends.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.colheader_justify</p></td>
# <td><p>right</p></td>
# <td><p>Controls the justification of
# column headers. used by DataFrameFormatter.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.column_space</p></td>
# <td><p>12</p></td>
# <td><p>No description available.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.date_dayfirst</p></td>
# <td><p>False</p></td>
# <td><p>When True, prints and parses dates
# with the day first, eg 20/01/2005</p></td>
# </tr>
# <tr class="row-even"><td><p>display.date_yearfirst</p></td>
# <td><p>False</p></td>
# <td><p>When True, prints and parses dates
# with the year first, eg 2005/01/20</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.encoding</p></td>
# <td><p>UTF-8</p></td>
# <td><p>Defaults to the detected encoding
# of the console. Specifies the encoding
# to be used for strings returned by
# to_string, these are generally strings
# meant to be displayed on the console.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.expand_frame_repr</p></td>
# <td><p>True</p></td>
# <td><p>Whether to print out the full DataFrame
# repr for wide DataFrames across
# multiple lines, <cite>max_columns</cite> is
# still respected, but the output will
# wrap-around across multiple “pages”
# if its width exceeds <cite>display.width</cite>.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.float_format</p></td>
# <td><p>None</p></td>
# <td><p>The callable should accept a floating
# point number and return a string with
# the desired format of the number.
# This is used in some places like
# SeriesFormatter.
# See core.format.EngFormatter for an example.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.large_repr</p></td>
# <td><p>truncate</p></td>
# <td><p>For DataFrames exceeding max_rows/max_cols,
# the repr (and HTML repr) can show
# a truncated table (the default),
# or switch to the view from df.info()
# (the behaviour in earlier versions of pandas).
# allowable settings, [‘truncate’, ‘info’]</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.latex.repr</p></td>
# <td><p>False</p></td>
# <td><p>Whether to produce a latex DataFrame
# representation for jupyter frontends
# that support it.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.latex.escape</p></td>
# <td><p>True</p></td>
# <td><p>Escapes special characters in DataFrames, when
# using the to_latex method.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.latex.longtable</p></td>
# <td><p>False</p></td>
# <td><p>Specifies if the to_latex method of a DataFrame
# uses the longtable format.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.latex.multicolumn</p></td>
# <td><p>True</p></td>
# <td><p>Combines columns when using a MultiIndex</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.latex.multicolumn_format</p></td>
# <td><p>‘l’</p></td>
# <td><p>Alignment of multicolumn labels</p></td>
# </tr>
# <tr class="row-even"><td><p>display.latex.multirow</p></td>
# <td><p>False</p></td>
# <td><p>Combines rows when using a MultiIndex.
# Centered instead of top-aligned,
# separated by clines.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.max_columns</p></td>
# <td><p>0 or 20</p></td>
# <td><p>max_rows and max_columns are used
# in __repr__() methods to decide if
# to_string() or info() is used to
# render an object to a string.  In
# case Python/IPython is running in
# a terminal this is set to 0 by default and
# pandas will correctly auto-detect
# the width of the terminal and switch to
# a smaller format in case all columns
# would not fit vertically. The IPython
# notebook, IPython qtconsole, or IDLE
# do not run in a terminal and hence
# it is not possible to do correct
# auto-detection, in which case the default
# is set to 20. ‘None’ value means unlimited.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.max_colwidth</p></td>
# <td><p>50</p></td>
# <td><p>The maximum width in characters of
# a column in the repr of a pandas
# data structure. When the column overflows,
# a “…” placeholder is embedded in
# the output. ‘None’ value means unlimited.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.max_info_columns</p></td>
# <td><p>100</p></td>
# <td><p>max_info_columns is used in DataFrame.info
# method to decide if per column information
# will be printed.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.max_info_rows</p></td>
# <td><p>1690785</p></td>
# <td><p>df.info() will usually show null-counts
# for each column. For large frames
# this can be quite slow. max_info_rows
# and max_info_cols limit this null
# check only to frames with smaller
# dimensions then specified.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.max_rows</p></td>
# <td><p>60</p></td>
# <td><p>This sets the maximum number of rows
# pandas should output when printing
# out various output. For example,
# this value determines whether the
# repr() for a dataframe prints out
# fully or just a truncated or summary repr.
# ‘None’ value means unlimited.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.min_rows</p></td>
# <td><p>10</p></td>
# <td><p>The numbers of rows to show in a truncated
# repr (when <cite>max_rows</cite> is exceeded). Ignored
# when <cite>max_rows</cite> is set to None or 0. When set
# to None, follows the value of <cite>max_rows</cite>.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.max_seq_items</p></td>
# <td><p>100</p></td>
# <td><p>when pretty-printing a long sequence,
# no more then <cite>max_seq_items</cite> will
# be printed. If items are omitted,
# they will be denoted by the addition
# of “…” to the resulting string.
# If set to None, the number of items
# to be printed is unlimited.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.memory_usage</p></td>
# <td><p>True</p></td>
# <td><p>This specifies if the memory usage of
# a DataFrame should be displayed when the
# df.info() method is invoked.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.multi_sparse</p></td>
# <td><p>True</p></td>
# <td><p>“Sparsify” MultiIndex display (don’t
# display repeated elements in outer
# levels within groups)</p></td>
# </tr>
# <tr class="row-even"><td><p>display.notebook_repr_html</p></td>
# <td><p>True</p></td>
# <td><p>When True, IPython notebook will
# use html representation for
# pandas objects (if it is available).</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.pprint_nest_depth</p></td>
# <td><p>3</p></td>
# <td><p>Controls the number of nested levels
# to process when pretty-printing</p></td>
# </tr>
# <tr class="row-even"><td><p>display.precision</p></td>
# <td><p>6</p></td>
# <td><p>Floating point output precision in
# terms of number of places after the
# decimal, for regular formatting as well
# as scientific notation. Similar to
# numpy’s <code class="docutils literal notranslate"><span class="pre">precision</span></code> print option</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.show_dimensions</p></td>
# <td><p>truncate</p></td>
# <td><p>Whether to print out dimensions
# at the end of DataFrame repr.
# If ‘truncate’ is specified, only
# print out the dimensions if the
# frame is truncated (e.g. not display
# all rows and/or columns)</p></td>
# </tr>
# <tr class="row-even"><td><p>display.width</p></td>
# <td><p>80</p></td>
# <td><p>Width of the display in characters.
# In case python/IPython is running in
# a terminal this can be set to None
# and pandas will correctly auto-detect
# the width. Note that the IPython notebook,
# IPython qtconsole, or IDLE do not run in a
# terminal and hence it is not possible
# to correctly detect the width.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.html.table_schema</p></td>
# <td><p>False</p></td>
# <td><p>Whether to publish a Table Schema
# representation for frontends that
# support it.</p></td>
# </tr>
# <tr class="row-even"><td><p>display.html.border</p></td>
# <td><p>1</p></td>
# <td><p>A <code class="docutils literal notranslate"><span class="pre">border=value</span></code> attribute is
# inserted in the <code class="docutils literal notranslate"><span class="pre">&lt;table&gt;</span></code> tag
# for the DataFrame HTML repr.</p></td>
# </tr>
# <tr class="row-odd"><td><p>display.html.use_mathjax</p></td>
# <td><p>True</p></td>
# <td><p>When True, Jupyter notebook will process
# table contents using MathJax, rendering
# mathematical expressions enclosed by the
# dollar symbol.</p></td>
# </tr>
# <tr class="row-even"><td><p>io.excel.xls.writer</p></td>
# <td><p>xlwt</p></td>
# <td><p>The default Excel writer engine for
# ‘xls’ files.</p></td>
# </tr>
# <tr class="row-odd"><td><p>io.excel.xlsm.writer</p></td>
# <td><p>openpyxl</p></td>
# <td><p>The default Excel writer engine for
# ‘xlsm’ files. Available options:
# ‘openpyxl’ (the default).</p></td>
# </tr>
# <tr class="row-even"><td><p>io.excel.xlsx.writer</p></td>
# <td><p>openpyxl</p></td>
# <td><p>The default Excel writer engine for
# ‘xlsx’ files.</p></td>
# </tr>
# <tr class="row-odd"><td><p>io.hdf.default_format</p></td>
# <td><p>None</p></td>
# <td><p>default format writing format, if
# None, then put will default to
# ‘fixed’ and append will default to
# ‘table’</p></td>
# </tr>
# <tr class="row-even"><td><p>io.hdf.dropna_table</p></td>
# <td><p>True</p></td>
# <td><p>drop ALL nan rows when appending
# to a table</p></td>
# </tr>
# <tr class="row-odd"><td><p>io.parquet.engine</p></td>
# <td><p>None</p></td>
# <td><p>The engine to use as a default for
# parquet reading and writing. If None
# then try ‘pyarrow’ and ‘fastparquet’</p></td>
# </tr>
# <tr class="row-even"><td><p>mode.chained_assignment</p></td>
# <td><p>warn</p></td>
# <td><p>Controls <code class="docutils literal notranslate"><span class="pre">SettingWithCopyWarning</span></code>:
# ‘raise’, ‘warn’, or None. Raise an
# exception, warn, or no action if
# trying to use <a class="reference internal" href="indexing.html#indexing-evaluation-order"><span class="std std-ref">chained assignment</span></a>.</p></td>
# </tr>
# <tr class="row-odd"><td><p>mode.sim_interactive</p></td>
# <td><p>False</p></td>
# <td><p>Whether to simulate interactive mode
# for purposes of testing.</p></td>
# </tr>
# <tr class="row-even"><td><p>mode.use_inf_as_na</p></td>
# <td><p>False</p></td>
# <td><p>True means treat None, NaN, -INF,
# INF as NA (old way), False means
# None and NaN are null, but INF, -INF
# are not NA (new way).</p></td>
# </tr>
# <tr class="row-odd"><td><p>compute.use_bottleneck</p></td>
# <td><p>True</p></td>
# <td><p>Use the bottleneck library to accelerate
# computation if it is installed.</p></td>
# </tr>
# <tr class="row-even"><td><p>compute.use_numexpr</p></td>
# <td><p>True</p></td>
# <td><p>Use the numexpr library to accelerate
# computation if it is installed.</p></td>
# </tr>
# <tr class="row-odd"><td><p>plotting.backend</p></td>
# <td><p>matplotlib</p></td>
# <td><p>Change the plotting backend to a different
# backend than the current matplotlib one.
# Backends can be implemented as third-party
# libraries implementing the pandas plotting
# API. They can use other plotting libraries
# like Bokeh, Altair, etc.</p></td>
# </tr>
# <tr class="row-even"><td><p>plotting.matplotlib.register_converters</p></td>
# <td><p>True</p></td>
# <td><p>Register custom converters with
# matplotlib. Set to False to de-register.</p></td>
# </tr>
# </tbody>
# </table>

# %%
pd.options.display.max_columns = 10
pd.options.display.max_rows = 10

# %%
pd.get_option('max_columns')
# Out:
# 10

# %%
pd.set_option('max_columns',10)

# %%
pd.describe_option('max_columns')
# Out:
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 20] [currently: 10]

# %%
pd.reset_option('max_columns')

# %%
pd.get_option('max_columns')
# Out:
# 20

# %%
pd.describe_option('max_columns')
# Out:
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 20] [currently: 20]

# %%
df = pd.read_csv('train.csv',parse_dates=[])

# %% [markdown]
# ### Series Functions

# %%
fare = pd.read_csv('train.csv',usecols=['Fare'],squeeze=True)

# %%
fare.dtype
# Out:
# dtype('float64')

# %%
type(fare)
# Out:
# pandas.core.series.Series

# %%
fare.head(5)
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
fare.tail(5)
# Out:
# 886    13.00
# 887    30.00
# 888    23.45
# 889    30.00
# 890     7.75
# Name: Fare, dtype: float64

# %%
# Sort a series by its values
fare.sort_values()
# Out:
# 271      0.0000
# 597      0.0000
# 302      0.0000
# 633      0.0000
# 277      0.0000
#          ...
# 438    263.0000
# 341    263.0000
# 737    512.3292
# 258    512.3292
# 679    512.3292
# Name: Fare, Length: 891, dtype: float64

# %%
# Sort a series by index
fare.sort_values().sort_index()
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
# after sorting by values index get ordered as per the sorting to get the original index we reset the index
fare.sort_values().reset_index(drop=True)
# Out:
# 0        0.0000
# 1        0.0000
# 2        0.0000
# 3        0.0000
# 4        0.0000
#          ...
# 886    263.0000
# 887    263.0000
# 888    512.3292
# 889    512.3292
# 890    512.3292
# Name: Fare, Length: 891, dtype: float64

# %%
fare[0]
# Out:
# 7.25

# %%
# Renaming the index values
fare.index = [f'Col{x}' for x in range(fare.size)]

# %%
fare['Col10']
# Out:
# 16.7

# %%
# to get a value from a series object
fare.get('Col100',default='Doesn\'t exist')
# Out:
# 7.8958

# %%
fare.get('Col1000',default='Doesn\'t exist')
# Out:
# "Doesn't exist"

# %%
# get index of the maximum value
fare.idxmax()
# Out:
# 'Col258'

# %%
# get index of the minimum value
fare.idxmin()
# Out:
# 'Col179'

# %%
# get value of index containing minimum value
fare.get(fare.idxmin())
# Out:
# 0.0

# %%
# get value of index containing maximum value
fare.get(fare.idxmax())
# Out:
# 512.3292

# %%
# apply a function to values in series object
fare.apply(lambda x: x*2.0)
# Out:
# Col0       14.5000
# Col1      142.5666
# Col2       15.8500
# Col3      106.2000
# Col4       16.1000
#             ...
# Col886     26.0000
# Col887     60.0000
# Col888     46.9000
# Col889     60.0000
# Col890     15.5000
# Name: Fare, Length: 891, dtype: float64

# %%
fare['Col10']
# Out:
# 16.7

# %%
fare[fare.between(100,500)]
# Out:
# Col27     263.0000
# Col31     146.5208
# Col88     263.0000
# Col118    247.5208
# Col195    146.5208
#             ...
# Col742    262.3750
# Col763    120.0000
# Col779    211.3375
# Col802    120.0000
# Col856    164.8667
# Name: Fare, Length: 50, dtype: float64

# %%
# retrun rows that have duplicate values
fare[fare.duplicated()]
# Out:
# Col12      8.050
# Col21     13.000
# Col24     21.075
# Col26      7.225
# Col37      8.050
#            ...
# Col886    13.000
# Col887    30.000
# Col888    23.450
# Col889    30.000
# Col890     7.750
# Name: Fare, Length: 643, dtype: float64

# %%
# return true if value in the series exists in the list provided otherwise false
fare.isin([7.5,30.0])
# Out:
# Col0      False
# Col1      False
# Col2      False
# Col3      False
# Col4      False
#           ...
# Col886    False
# Col887     True
# Col888    False
# Col889     True
# Col890    False
# Name: Fare, Length: 891, dtype: bool

# %%
# Rank the values in the series
fare.rank(ascending=False)
# Out:
# Col0      815.0
# Col1      103.0
# Col2      659.5
# Col3      144.0
# Col4      628.0
#           ...
# Col886    484.5
# Col887    237.5
# Col888    345.5
# Col889    237.5
# Col890    768.5
# Name: Fare, Length: 891, dtype: float64

# %% [markdown]
# ### Dataframe Functions
#
# Series and Dataframe shares many functions together

# %%
# value_counts() returns the count of unique values in the series
# plot() to plot data provided as series
df['Survived'].value_counts().plot(kind='hist',bins=3) # pie bar line hist # bins = no of columns

# %%
# insert a value at the specified position
df.insert(2,"Sum",df.sum(axis=1))

# %%
df["Sum"].head()
# Out:
# 0     34.2500
# 1    114.2833
# 2     40.9250
# 3     95.1000
# 4     51.0500
# Name: Sum, dtype: float64

# %%
df.Age.isin([5,10,20,25,35,28])
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
# return true if the value is null otherwise false
df.isnull()
# Out:
#      PassengerId  Survived    Sum  Pclass   Name    Sex    Age  SibSp  Parch  \
# 0          False     False  False   False  False  False  False  False  False
# 1          False     False  False   False  False  False  False  False  False
# 2          False     False  False   False  False  False  False  False  False
# 3          False     False  False   False  False  False  False  False  False
# 4          False     False  False   False  False  False  False  False  False
# ..           ...       ...    ...     ...    ...    ...    ...    ...    ...
# 886        False     False  False   False  False  False  False  False  False
# 887        False     False  False   False  False  False  False  False  False
# 888        False     False  False   False  False  False   True  False  False
# 889        False     False  False   False  False  False  False  False  False
# 890        False     False  False   False  False  False  False  False  False
#
#      Ticket   Fare  Cabin  Embarked
# ...

# %%
df.shape
# Out:
# (891, 13)

# %%
# extract subset of values from a dataframe
df.iloc[df.Age.drop_duplicates().index]
# Out:
#      PassengerId  Survived       Sum  Pclass  \
# 0              1         0   34.2500       3
# 1              2         1  114.2833       1
# 2              3         1   40.9250       3
# 3              4         1   95.1000       1
# 5              6         0   17.4583       3
# ..           ...       ...       ...     ...
# 755          756         1  776.1700       2
# 767          768         0  809.2500       3
# 803          804         1  817.9367       3
# 843          844         0  887.9375       3
# 851          852         0  936.7750       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived       Sum  Pclass  \
# 0            1         0   34.2500       3
# 1            2         1  114.2833       1
# 2            3         1   40.9250       3
# 3            4         1   95.1000       1
# 4            5         0   51.0500       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# iloc[]
# loc[]
# ix[]
#
# can be used to get and set values in dataframe

# %%
df.iloc[0:10,2:5]
# Out:
#         Sum  Pclass                                               Name
# 0   34.2500       3                            Braund, Mr. Owen Harris
# 1  114.2833       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   40.9250       3                             Heikkinen, Miss. Laina
# 3   95.1000       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   51.0500       3                           Allen, Mr. William Henry
# 5   17.4583       3                                   Moran, Mr. James
# 6  113.8625       1                            McCarthy, Mr. Timothy J
# 7   38.0750       3                     Palsson, Master. Gosta Leonard
# 8   53.1333       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9   58.0708       2                Nasser, Mrs. Nicholas (Adele Achem)

# %%
df.loc[0,["Fare","Survived"]] = [10.0,1]

# %%
df.drop(['Age'],axis=1) # remove Age column
# Out:
#      PassengerId  Survived       Sum  Pclass  \
# 0              1         1   34.2500       3
# 1              2         1  114.2833       1
# 2              3         1   40.9250       3
# 3              4         1   95.1000       1
# 4              5         0   51.0500       3
# ..           ...       ...       ...     ...
# 886          887         0  929.0000       2
# 887          888         1  939.0000       1
# 888          889         0  918.4500       3
# 889          890         1  948.0000       1
# 890          891         0  933.7500       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived       Sum  Pclass  \
# 0            1         1   34.2500       3
# 1            2         1  114.2833       1
# 2            3         1   40.9250       3
# 3            4         1   95.1000       1
# 4            5         0   51.0500       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171  10.0000   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Rename a single column
df.rename({"Fare":"Ticker_Price"},axis=1)
# Out:
#      PassengerId  Survived       Sum  Pclass  \
# 0              1         1   34.2500       3
# 1              2         1  114.2833       1
# 2              3         1   40.9250       3
# 3              4         1   95.1000       1
# 4              5         0   51.0500       3
# ..           ...       ...       ...     ...
# 886          887         0  929.0000       2
# 887          888         1  939.0000       1
# 888          889         0  918.4500       3
# 889          890         1  948.0000       1
# 890          891         0  933.7500       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
# Rename all columns
# df.columns = list of columns name equal to size of df.columns

# %%
df.sample(n=100)
# Out:
#      PassengerId  Survived       Sum  Pclass  \
# 591          592         1  725.2667       1
# 201          202         0  284.5500       3
# 33            34         0  112.5000       2
# 364          365         0  384.5000       3
# 223          224         0  234.8958       3
# ..           ...       ...       ...     ...
# 846          847         0  929.5500       3
# 482          483         0  544.0500       3
# 137          138         0  230.1000       1
# 676          677         0  712.5500       3
# 796          797         1  873.9292       1
#
#                                                 Name     Sex   Age  SibSp  \
# 591  Stephenson, Mrs. Walter Bertram (Martha Eustis)  female  52.0      1
# 201                              Sage, Mr. Frederick    male   NaN      8
# 33                             Wheadon, Mr. Edward H    male  66.0      0
# 364                              O'Brien, Mr. Thomas    male   NaN      1
# ...

# %%
# Get columns with N largest values for the specified rows
df.nlargest(10,columns=['Fare','Sum'])
# Out:
#      PassengerId  Survived        Sum  Pclass  \
# 737          738         1  1287.3292       1
# 679          680         1  1231.3292       1
# 258          259         1   808.3292       1
# 438          439         0   772.0000       1
# 341          342         1   636.0000       1
# 88            89         1   382.0000       1
# 27            28         0   316.0000       1
# 742          743         1  1032.3750       1
# 311          312         1   598.3750       1
# 299          300         1   600.5208       1
#
#                                                 Name     Sex   Age  SibSp  \
# 737                           Lesurer, Mr. Gustave J    male  35.0      0
# 679               Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 258                                 Ward, Miss. Anna  female  35.0      0
# 438                                Fortune, Mr. Mark    male  64.0      1
# 341                   Fortune, Miss. Alice Elizabeth  female  24.0      3
# ...

# %%
# Get columns with N smallest values for the specified rows
df.nsmallest(10,columns=['Fare','Sum'])
# Out:
#      PassengerId  Survived    Sum  Pclass                              Name  \
# 179          180         0  219.0       3               Leonard, Mr. Lionel
# 277          278         0  280.0       2       Parkes, Mr. Francis "Frank"
# 271          272         1  301.0       3      Tornquist, Mr. William Henry
# 263          264         0  305.0       1             Harrison, Mr. William
# 302          303         0  325.0       3   Johnson, Mr. William Cahoone Jr
# 413          414         0  416.0       2    Cunningham, Mr. Alfred Fleming
# 466          467         0  469.0       2             Campbell, Mr. William
# 481          482         0  484.0       2  Frost, Mr. Anthony Wood "Archie"
# 633          634         0  635.0       1     Parr, Mr. William Henry Marsh
# 597          598         0  650.0       3               Johnson, Mr. Alfred
#
#       Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 179  male  36.0      0      0    LINE   0.0   NaN        S
# ...

# %%
# df.where(condition) get full dataframe satisfying the condition with other as null values

# %%
# keep the values where the condition is met otherwise put value specified in 'other'
df.where(df.Sex == 'male') #,other=lambda x: x)
# Out:
#      PassengerId  Survived     Sum  Pclass                      Name   Sex  \
# 0            1.0       1.0   34.25     3.0   Braund, Mr. Owen Harris  male
# 1            NaN       NaN     NaN     NaN                       NaN   NaN
# 2            NaN       NaN     NaN     NaN                       NaN   NaN
# 3            NaN       NaN     NaN     NaN                       NaN   NaN
# 4            5.0       0.0   51.05     3.0  Allen, Mr. William Henry  male
# ..           ...       ...     ...     ...                       ...   ...
# 886        887.0       0.0  929.00     2.0     Montvila, Rev. Juozas  male
# 887          NaN       NaN     NaN     NaN                       NaN   NaN
# 888          NaN       NaN     NaN     NaN                       NaN   NaN
# 889        890.0       1.0  948.00     1.0     Behr, Mr. Karl Howell  male
# 890        891.0       0.0  933.75     3.0       Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# ...

# %%
# to get rows that satisfy the given condition. Conditions with relational and conditional operators.
df.query('Survived == "1"')
# Out:
#      PassengerId  Survived        Sum  Pclass  \
# 0              1         1    34.2500       3
# 1              2         1   114.2833       1
# 2              3         1    40.9250       3
# 3              4         1    95.1000       1
# 8              9         1    53.1333       3
# ..           ...       ...        ...     ...
# 875          876         1   902.2250       3
# 879          880         1  1022.1583       1
# 880          881         1   936.0000       2
# 887          888         1   939.0000       1
# 889          890         1   948.0000       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
def namefunct(name):
    if(len(name) > 10):
        return True
    else:
        return False
df["Name"].apply(namefunct)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: Name, Length: 891, dtype: bool

# %%
# MultiIndex
df_multiindex = pd.read_csv('train.csv',index_col=['Sex','Age'])

# %%
df_multiindex.head(10)
# Out:
#              PassengerId  Survived  Pclass  \
# Sex    Age
# male   22.0            1         0       3
# female 38.0            2         1       1
#        26.0            3         1       3
#        35.0            4         1       1
# male   35.0            5         0       3
#        NaN             6         0       3
#        54.0            7         0       1
#        2.0             8         0       3
# female 27.0            9         1       3
#        14.0           10         1       2
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# male   22.0                            Braund, Mr. Owen Harris      1      0
# female 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
#        26.0                             Heikkinen, Miss. Laina      0      0
#        35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# ...

# %%
df_multiindex.index.set_names(names=['sex','age'])
# Out:
# MultiIndex([(  'male', 22.0),
#             ('female', 38.0),
#             ('female', 26.0),
#             ('female', 35.0),
#             (  'male', 35.0),
#             (  'male',  nan),
#             (  'male', 54.0),
#             (  'male',  2.0),
#             ('female', 27.0),
#             ('female', 14.0),
#             ...
#             (  'male', 33.0),
#             ('female', 22.0),
#             (  'male', 28.0),
#             (  'male', 25.0),
#             ('female', 39.0),
#             (  'male', 27.0),
#             ('female', 19.0),
#             ('female',  nan),
#             (  'male', 26.0),
#             (  'male', 32.0)],
#            names=['sex', 'age'], length=891)

# %%
df_multiindex.index.set_names(names="AGE",level=1)
# Out:
# MultiIndex([(  'male', 22.0),
#             ('female', 38.0),
#             ('female', 26.0),
#             ('female', 35.0),
#             (  'male', 35.0),
#             (  'male',  nan),
#             (  'male', 54.0),
#             (  'male',  2.0),
#             ('female', 27.0),
#             ('female', 14.0),
#             ...
#             (  'male', 33.0),
#             ('female', 22.0),
#             (  'male', 28.0),
#             (  'male', 25.0),
#             ('female', 39.0),
#             (  'male', 27.0),
#             ('female', 19.0),
#             ('female',  nan),
#             (  'male', 26.0),
#             (  'male', 32.0)],
#            names=['Sex', 'AGE'], length=891)

# %%
df_multiindex.sort_index(ascending=False,level=0)
# Out:
#              PassengerId  Survived  Pclass  \
# Sex    Age
# male   80.0          631         1       1
#        74.0          852         0       3
#        71.0          494         0       1
#        71.0           97         0       1
#        70.5          117         0       3
# ...                  ...       ...     ...
# female NaN            48         1       3
#        NaN            33         1       3
#        NaN            32         1       1
#        NaN            29         1       3
#        NaN            20         1       3
#
#                                                        Name  SibSp  Parch  \
# Sex    Age
# male   80.0            Barkworth, Mr. Algernon Henry Wilson      0      0
#        74.0                             Svensson, Mr. Johan      0      0
#        71.0                         Artagaveytia, Mr. Ramon      0      0
#        71.0                       Goldschmidt, Mr. George B      0      0
# ...

# %%
df_multiindex.loc[('male',35)]
# Out:
# /home/apptica/anaconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#            PassengerId  Survived  Pclass                              Name  \
# Sex  Age
# male 35.0            5         0       3          Allen, Mr. William Henry
#      35.0           21         0       2              Fynney, Mr. Joseph J
#      35.0          364         0       3                   Asim, Mr. Adola
#      35.0          591         0       3              Rintamaki, Mr. Matti
#      35.0          605         1       1   Homer, Mr. Harry ("Mr E Haven")
#      35.0          615         0       3   Brocklebank, Mr. William Alfred
#      35.0          702         1       1  Silverthorne, Mr. Spencer Victor
#      35.0          738         1       1            Lesurer, Mr. Gustave J
#      35.0          813         0       2         Slemen, Mr. Richard James
# ...

# %%
df_multiindex.iloc[[10,20,40]]
# Out:
#              PassengerId  Survived  Pclass  \
# Sex    Age
# female 4.0            11         1       3
# male   35.0           21         0       2
# female 40.0           41         0       3
#
#                                                        Name  SibSp  Parch  \
# Sex    Age
# female 4.0                  Sandstrom, Miss. Marguerite Rut      1      1
# male   35.0                            Fynney, Mr. Joseph J      0      0
# female 40.0  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)      1      0
#
#               Ticket    Fare Cabin Embarked
# Sex    Age
# female 4.0   PP 9549  16.700    G6        S
# male   35.0   239865  26.000   NaN        S
# female 40.0     7546   9.475   NaN        S

# %%
df_multiindex.transpose()
# Out:
# Sex                             male  \
# Age                             22.0
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
# Sex                                                     female  \
# Age                                                       38.0
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# SibSp                                                        1
# Parch                                                        0
# ...

# %%
df_multiindex.swaplevel(0,1)
# Out:
#              PassengerId  Survived  Pclass  \
# Age  Sex
# 22.0 male              1         0       3
# 38.0 female            2         1       1
# 26.0 female            3         1       3
# 35.0 female            4         1       1
#      male              5         0       3
# ...                  ...       ...     ...
# 27.0 male            887         0       2
# 19.0 female          888         1       1
# NaN  female          889         0       3
# 26.0 male            890         1       1
# 32.0 male            891         0       3
#
#                                                           Name  SibSp  Parch  \
# Age  Sex
# 22.0 male                              Braund, Mr. Owen Harris      1      0
# 38.0 female  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# 26.0 female                             Heikkinen, Miss. Laina      0      0
# 35.0 female       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# ...

# %%
df_multiindex.stack()
# Out:
# Sex   Age
# male  22.0  PassengerId                          1
#             Survived                             0
#             Pclass                               3
#             Name           Braund, Mr. Owen Harris
#             SibSp                                1
#                                     ...
#       32.0  SibSp                                0
#             Parch                                0
#             Ticket                          370376
#             Fare                              7.75
#             Embarked                             Q
# Length: 8221, dtype: object

# %%
# Takes innermost index and makes it columns
df.unstack()
# Out:
# PassengerId  0      1
#              1      2
#              2      3
#              3      4
#              4      5
#                    ..
# Embarked     886    S
#              887    S
#              888    S
#              889    C
#              890    Q
# Length: 11583, dtype: object

# %%
# It takes the specified level of index and makes it column
df.unstack(level=[1]) # df.unstack(level=[0,1])
# Out:
# PassengerId  0      1
#              1      2
#              2      3
#              3      4
#              4      5
#                    ..
# Embarked     886    S
#              887    S
#              888    S
#              889    C
#              890    Q
# Length: 11583, dtype: object

# %%
df.pivot(index = "PassengerId",values=['Fare','Sum'],columns='Sex')
# Out:
#                 Fare              Sum
# Sex           female   male    female    male
# PassengerId
# 1                NaN  10.00       NaN   34.25
# 2            71.2833    NaN  114.2833     NaN
# 3             7.9250    NaN   40.9250     NaN
# 4            53.1000    NaN   95.1000     NaN
# 5                NaN   8.05       NaN   51.05
# ...              ...    ...       ...     ...
# 887              NaN  13.00       NaN  929.00
# 888          30.0000    NaN  939.0000     NaN
# 889          23.4500    NaN  918.4500     NaN
# 890              NaN  30.00       NaN  948.00
# 891              NaN   7.75       NaN  933.75
#
# [891 rows x 4 columns]

# %%
df.pivot_table(values='Fare',index=['Sex','Embarked'],columns=['Survived'])
# Out:
# Survived                 0          1
# Sex    Embarked
# female C         16.215278  83.460286
#        Q         10.904633  13.211733
#        S         25.728508  44.596518
# male   C         38.065342  71.468545
#        Q         13.911732  12.916667
#        S         19.916078  30.105179

# %%
# Organize and reorient the dataframe to get more insight about the data by representing column as variable
pd.melt(df,var_name='Info',value_name='data',id_vars=['Sex','Embarked'],value_vars=['Survived','Fare','Sum'])
# Out:
#          Sex Embarked      Info    data
# 0       male        S  Survived    1.00
# 1     female        C  Survived    1.00
# 2     female        S  Survived    1.00
# 3     female        S  Survived    1.00
# 4       male        S  Survived    0.00
# ...      ...      ...       ...     ...
# 2668    male        S       Sum  929.00
# 2669  female        S       Sum  939.00
# 2670  female        S       Sum  918.45
# 2671    male        C       Sum  948.00
# 2672    male        Q       Sum  933.75
#
# [2673 rows x 4 columns]

# %%
Pclass = df.groupby(["Pclass","Survived"])

# %%
Pclass.size()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           371
#         1           120
# dtype: int64

# %%
Pclass.first()
# Out:
#                  PassengerId       Sum  \
# Pclass Survived
# 1      0                   7  113.8625
#        1                   2  114.2833
# 2      0                  21   84.0000
#        1                  10   58.0708
# 3      0                   5   51.0500
#        1                   1   34.2500
#
#                                                               Name     Sex  \
# Pclass Survived
# 1      0                                   McCarthy, Mr. Timothy J    male
#        1         Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2      0                                      Fynney, Mr. Joseph J    male
#        1                       Nasser, Mrs. Nicholas (Adele Achem)  female
# 3      0                                  Allen, Mr. William Henry    male
#        1                                   Braund, Mr. Owen Harris    male
#
#                   Age  SibSp  Parch     Ticket     Fare  Cabin Embarked
# Pclass Survived
# ...

# %%
Pclass.last()
# Out:
#                  PassengerId      Sum  \
# Pclass Survived
# 1      0                 873  912.000
#        1                 890  948.000
# 2      0                 887  929.000
#        1                 881  936.000
# 3      0                 891  933.750
#        1                 876  902.225
#
#                                                          Name     Sex   Age  \
# Pclass Survived
# 1      0                             Carlsson, Mr. Frans Olof    male  33.0
#        1                                Behr, Mr. Karl Howell    male  26.0
# 2      0                                Montvila, Rev. Juozas    male  27.0
#        1         Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 3      0                                  Dooley, Mr. Patrick    male  32.0
#        1                     Najib, Miss. Adele Kiamie "Jane"  female  15.0
#
#                  SibSp  Parch  Ticket    Fare        Cabin Embarked
# Pclass Survived
# ...

# %%
Pclass.groups
# Out:
# {(1,
#   0): Int64Index([  6,  27,  30,  34,  35,  54,  62,  64,  83,  92,  96, 102, 110,
#              118, 124, 137, 139, 155, 168, 170, 174, 177, 185, 245, 252, 262,
#              263, 270, 273, 284, 295, 297, 331, 332, 336, 339, 351, 373, 377,
#              434, 438, 452, 456, 462, 467, 475, 487, 492, 493, 498, 505, 515,
#              527, 536, 544, 545, 555, 557, 583, 602, 625, 633, 659, 662, 671,
#              694, 698, 711, 741, 745, 748, 766, 782, 789, 793, 806, 815, 822,
#              867, 872],
#             dtype='int64'),
#  (1, 1): Int64Index([  1,   3,  11,  23,  31,  52,  55,  61,  88,  97,
#              ...
#              842, 849, 853, 856, 857, 862, 871, 879, 887, 889],
#             dtype='int64', length=136),
#  (2,
#   0): Int64Index([ 20,  33,  41,  70,  72,  99, 117, 120, 122, 134, 135, 144, 145,
#              148, 149, 150, 178, 181, 191, 199, 213, 217, 219, 221, 228, 232,
#              234, 236, 238, 239, 242, 249, 265, 277, 292, 308, 312, 314, 317,
# ...

# %%
Pclass.get_group((1,0))
# Out:
#      PassengerId       Sum                                  Name   Sex   Age  \
# 6              7  113.8625               McCarthy, Mr. Timothy J  male  54.0
# 27            28  316.0000        Fortune, Mr. Charles Alexander  male  19.0
# 30            31   99.7208              Uruchurtu, Don. Manuel E  male  40.0
# 34            35  147.1708               Meyer, Mr. Edgar Joseph  male  28.0
# 35            36  132.0000        Holverson, Mr. Alexander Oskar  male  42.0
# ..           ...       ...                                   ...   ...   ...
# 806          807  847.0000                Andrews, Mr. Thomas Jr  male  39.0
# 815          816  817.0000                      Fry, Mr. Richard  male   NaN
# 822          823  862.0000       Reuchlin, Jonkheer. John George  male  38.0
# 867          868  950.4958  Roebling, Mr. Washington Augustus II  male  31.0
# 872          873  912.0000              Carlsson, Mr. Frans Olof  male  33.0
#
# ...

# %%
Pclass.mean()
# Out:
#                  PassengerId         Sum        Age     SibSp     Parch  \
# Pclass Survived
# 1      0          410.300000  511.527757  43.695312  0.287500  0.300000
#        1          491.772059  621.989793  35.368197  0.492647  0.389706
# 2      0          452.123711  505.123668  33.544444  0.319588  0.144330
#        1          439.080460  489.984780  25.901566  0.494253  0.643678
# 3      0          454.800539  491.810656  26.572491  0.671159  0.385445
#        1          390.783333  424.082180  20.661860  0.441667  0.416667
#
#                       Fare
# Pclass Survived
# 1      0         64.684008
#        1         95.608029
# 2      0         19.412328
#        1         22.055700
# 3      0         13.686667
#        1         13.664097

# %%
Pclass.max()
# Out:
#                   Age      Fare                          Name  Parch  \
# Pclass Survived
# 1      0         71.0  263.0000            Wright, Mr. George      4
#        1         80.0  512.3292      Young, Miss. Marie Grice      2
# 2      0         70.0   73.5000     del Carlo, Mr. Sebastiano      2
#        1         62.0   65.0000  Williams, Mr. Charles Eugene      3
# 3      0         74.0   69.5500   van Melkebeke, Mr. Philemon      6
#        1         63.0   56.4958       de Mulder, Mr. Theodore      5
#
#                  PassengerId   Sex  SibSp        Sum            Ticket
# Pclass Survived
# 1      0                 873  male      3   950.4958         WE/P 5735
#        1                 890  male      3  1287.3292         WE/P 5735
# 2      0                 887  male      2   929.0000         W/C 14208
#        1                 881  male      3   936.0000       W./C. 14258
# 3      0                 891  male      8   962.1250        W./C. 6609
# ...

# %%
Pclass[["Fare","Age"]].max()
# Out:
#                      Fare   Age
# Pclass Survived
# 1      0         263.0000  71.0
#        1         512.3292  80.0
# 2      0          73.5000  70.0
#        1          65.0000  62.0
# 3      0          69.5500  74.0
#        1          56.4958  63.0

# %%
Pclass.agg(["size","sum","mean"])
# Out:
#                 PassengerId                      Sum                           \
#                        size     sum        mean size          sum        mean
# Pclass Survived
# 1      0                 80   32824  410.300000   80   40922.2206  511.527757
#        1                136   66881  491.772059  136   84590.6119  621.989793
# 2      0                 97   43856  452.123711   97   48996.9958  505.123668
#        1                 87   38200  439.080460   87   42628.6759  489.984780
# 3      0                371  168731  454.800539  371  182461.7535  491.810656
#        1                120   46894  390.783333  120   50889.8616  424.082180
#
#                  Age                     SibSp                Parch       \
#                 size      sum       mean  size  sum      mean  size  sum
# Pclass Survived
# 1      0          80  2796.50  43.695312    80   23  0.287500    80   24
#        1         136  4314.92  35.368197   136   67  0.492647   136   53
# ...

# %%
Pclass.agg({
    "PassengerId":"size",
    "Fare":"mean",
    "Ticket":"max"
})
# Out:
#                  PassengerId       Fare            Ticket
# Pclass Survived
# 1      0                  80  64.684008         WE/P 5735
#        1                 136  95.608029         WE/P 5735
# 2      0                  97  19.412328         W/C 14208
#        1                  87  22.055700       W./C. 14258
# 3      0                 371  13.686667        W./C. 6609
#        1                 120  13.664097  STON/O2. 3101283

# %%
df1 = pd.read_csv('train.csv',index_col='PassengerId',usecols=['PassengerId','Survived','Sex'])
df2 = pd.read_csv('train.csv',index_col='PassengerId',usecols=['PassengerId','Embarked','Age'])

# %%
pd.concat([df1,df2],axis=1)
# Out:
#              Survived     Sex   Age Embarked
# PassengerId
# 1                   0    male  22.0        S
# 2                   1  female  38.0        C
# 3                   1  female  26.0        S
# 4                   1  female  35.0        S
# 5                   0    male  35.0        S
# ...               ...     ...   ...      ...
# 887                 0    male  27.0        S
# 888                 1  female  19.0        S
# 889                 0  female   NaN        S
# 890                 1    male  26.0        C
# 891                 0    male  32.0        Q
#
# [891 rows x 4 columns]

# %%
df1 = pd.read_csv('train.csv',usecols=['PassengerId','Survived','Sex','Fare'])
df2 = pd.read_csv('train.csv',usecols=['PassengerId','Survived','Embarked','Age'])

# %%
df1.merge(df2,on='PassengerId')
# Out:
#      PassengerId  Survived_x     Sex     Fare  Survived_y   Age Embarked
# 0              1           0    male   7.2500           0  22.0        S
# 1              2           1  female  71.2833           1  38.0        C
# 2              3           1  female   7.9250           1  26.0        S
# 3              4           1  female  53.1000           1  35.0        S
# 4              5           0    male   8.0500           0  35.0        S
# ..           ...         ...     ...      ...         ...   ...      ...
# 886          887           0    male  13.0000           0  27.0        S
# 887          888           1  female  30.0000           1  19.0        S
# 888          889           0  female  23.4500           0   NaN        S
# 889          890           1    male  30.0000           1  26.0        C
# 890          891           0    male   7.7500           0  32.0        Q
#
# [891 rows x 7 columns]

# %%
df2 = pd.read_csv('train.csv',usecols=['PassengerId','Survived','Embarked','Age'])
df2.columns = ['TempId','survived','embark','age']

# %%
df1.merge(df2,left_on='PassengerId',right_on='TempId')
# Out:
#      PassengerId  Survived     Sex     Fare  TempId  survived  embark age
# 0              1         0    male   7.2500       1         0    22.0   S
# 1              2         1  female  71.2833       2         1    38.0   C
# 2              3         1  female   7.9250       3         1    26.0   S
# 3              4         1  female  53.1000       4         1    35.0   S
# 4              5         0    male   8.0500       5         0    35.0   S
# ..           ...       ...     ...      ...     ...       ...     ...  ..
# 886          887         0    male  13.0000     887         0    27.0   S
# 887          888         1  female  30.0000     888         1    19.0   S
# 888          889         0  female  23.4500     889         0     NaN   S
# 889          890         1    male  30.0000     890         1    26.0   C
# 890          891         0    male   7.7500     891         0    32.0   Q
#
# [891 rows x 8 columns]

# %%
columns = pd.read_csv('train.csv',nrows=0,squeeze=True).columns

# %%
columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1 = pd.read_csv('train.csv',header=None,names=columns,usecols=['PassengerId','Survived','Sex','Fare'],skiprows=100,nrows=100)
df2 = pd.read_csv('train.csv',header=None,names=columns,usecols=['PassengerId','Survived','Embarked','Age'],skiprows=150,nrows=100)
print(df2.head(2))
print(df2.tail(2))
df2.rename({'PassengerId':'TempId'},axis=1,inplace=True)
df1.merge(df2,left_on='PassengerId',right_on='TempId',how='outer',indicator=True)
# Out:
#    PassengerId  Survived   Age Embarked
# 0          150         0  42.0        S
# 1          151         0  51.0        S
#     PassengerId  Survived   Age Embarked
# 98          248         1  24.0        S
# 99          249         1  37.0        S
#      PassengerId  Survived_x     Sex     Fare  TempId  Survived_y   Age  \
# 0          100.0         0.0    male  26.0000     NaN         NaN   NaN
# 1          101.0         0.0  female   7.8958     NaN         NaN   NaN
# 2          102.0         0.0    male   7.8958     NaN         NaN   NaN
# 3          103.0         0.0    male  77.2875     NaN         NaN   NaN
# 4          104.0         0.0    male   8.6542     NaN         NaN   NaN
# ..           ...         ...     ...      ...     ...         ...   ...
# 145          NaN         NaN     NaN      NaN   245.0         0.0  30.0
# 146          NaN         NaN     NaN      NaN   246.0         0.0  44.0
# 147          NaN         NaN     NaN      NaN   247.0         0.0  25.0
# ...

# %%
df1.merge(df2,left_on='PassengerId',right_on='TempId',how='outer',indicator=True)['_merge'].value_counts()
# Out:
# both          50
# right_only    50
# left_only     50
# Name: _merge, dtype: int64

# %%
df1 = pd.read_csv('train.csv',usecols=['PassengerId','Survived','Sex','Fare'],nrows=250)
df2 = pd.read_csv('train.csv',header=None,names=columns,usecols=['PassengerId','Survived','Embarked','Age'],skiprows=150,nrows=100)
df2.rename({'PassengerId':'TempId'},axis=1,inplace=True)
df1.merge(df2,left_on=['PassengerId','Survived'],right_on=['TempId','Survived'],how='left',indicator=True)
# Out:
#      PassengerId  Survived     Sex     Fare  TempId   Age Embarked     _merge
# 0              1         0    male   7.2500     NaN   NaN      NaN  left_only
# 1              2         1  female  71.2833     NaN   NaN      NaN  left_only
# 2              3         1  female   7.9250     NaN   NaN      NaN  left_only
# 3              4         1  female  53.1000     NaN   NaN      NaN  left_only
# 4              5         0    male   8.0500     NaN   NaN      NaN  left_only
# ..           ...       ...     ...      ...     ...   ...      ...        ...
# 245          246         0    male  90.0000   246.0  44.0        Q       both
# 246          247         0  female   7.7750   247.0  25.0        S       both
# 247          248         1  female  14.5000   248.0  24.0        S       both
# 248          249         1    male  52.5542   249.0  37.0        S       both
# 249          250         0    male  26.0000     NaN   NaN      NaN  left_only
#
# [250 rows x 8 columns]

# %%
df1.merge(df2,left_on=['PassengerId','Survived'],right_on=['TempId','Survived'],how='left',indicator=True)['_merge'].value_counts()
# Out:
# left_only     150
# both          100
# right_only      0
# Name: _merge, dtype: int64

# %%
df1 = pd.read_csv('train.csv',usecols=['PassengerId','Survived','Sex','Fare'],nrows=250,index_col=['PassengerId','Survived'])
df2 = pd.read_csv('train.csv',header=None,names=columns,usecols=['PassengerId','Survived','Embarked','Age'],skiprows=150,nrows=100)
df1.merge(df2,on = ['PassengerId','Survived'],how='left',left_index=True,indicator=True)
# Out:
#     PassengerId  Survived     Sex     Fare   Age Embarked     _merge
# 99            1         0    male   7.2500   NaN      NaN  left_only
# 99            2         1  female  71.2833   NaN      NaN  left_only
# 99            3         1  female   7.9250   NaN      NaN  left_only
# 99            4         1  female  53.1000   NaN      NaN  left_only
# 99            5         0    male   8.0500   NaN      NaN  left_only
# ..          ...       ...     ...      ...   ...      ...        ...
# 96          246         0    male  90.0000  44.0        Q       both
# 97          247         0  female   7.7750  25.0        S       both
# 98          248         1  female  14.5000  24.0        S       both
# 99          249         1    male  52.5542  37.0        S       both
# 99          250         0    male  26.0000   NaN      NaN  left_only
#
# [250 rows x 7 columns]

# %% [markdown]
# #### Note: merge method is used to join bases on columns but join method uses index to perform join

# %%
pd.Timestamp('1/12/2020')
# Out:
# Timestamp('2020-01-12 00:00:00')

# %%
dates = ['1/12/2020','2/12/2020','3/12/2020']
date_index = pd.DatetimeIndex(dates)

# %%
date_index
# Out:
# DatetimeIndex(['2020-01-12', '2020-02-12', '2020-03-12'], dtype='datetime64[ns]', freq=None)

# %%
values = [100,200,300]
date_obj = pd.Series(values,index=date_index)
pd.Series(values,index=date_index)
# Out:
# 2020-01-12    100
# 2020-02-12    200
# 2020-03-12    300
# dtype: int64

# %%
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2020-01-12', '2020-02-12', '2020-03-12'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('July 4 2020')
# Out:
# Timestamp('2020-07-04 00:00:00')

# %%
pd.date_range(start='2020-01-01',end='2020-12-01',freq='D') # freq = H(hourinterval) D(dayinterval) W(weekinterval) M(monthinterval) MS(monthstart) A(yearinterval) pd.DataOffset
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-11-22', '2020-11-23', '2020-11-24', '2020-11-25',
#                '2020-11-26', '2020-11-27', '2020-11-28', '2020-11-29',
#                '2020-11-30', '2020-12-01'],
#               dtype='datetime64[ns]', length=336, freq='D')

# %%
pd.date_range(start='2020-01-01',periods=10,freq='4M') # freq = H(hourinterval) D(dayinterval) W(weekinterval) M(monthinterval) MS(monthstart) A(yearinterval) pd.DataOffset 6H(6 hour interval) 6M(6 month interval)
# Out:
# DatetimeIndex(['2020-01-31', '2020-05-31', '2020-09-30', '2021-01-31',
#                '2021-05-31', '2021-09-30', '2022-01-31', '2022-05-31',
#                '2022-09-30', '2023-01-31'],
#               dtype='datetime64[ns]', freq='4M')

# %%
# pd.Dataofffset allows to add or subtract specific amount of time form the datetime object
date_obj.index + pd.DateOffset(weeks=1)
# Out:
# DatetimeIndex(['2020-01-19', '2020-02-19', '2020-03-19'], dtype='datetime64[ns]', freq=None)

# %%
pd.date_range(start='2020-01-01',periods=10,freq=pd.tseries.offsets.SemiMonthBegin())
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-15', '2020-02-01', '2020-02-15',
#                '2020-03-01', '2020-03-15', '2020-04-01', '2020-04-15',
#                '2020-05-01', '2020-05-15'],
#               dtype='datetime64[ns]', freq='SMS-15')

# %%
date_obj.index + pd.Timedelta(weeks=10)
# Out:
# DatetimeIndex(['2020-03-22', '2020-04-22', '2020-05-21'], dtype='datetime64[ns]', freq=None)
